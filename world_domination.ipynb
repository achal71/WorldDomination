# %% [markdown]
# <a href="https://colab.research.google.com/github/achal71/WorldDomination/blob/main/world_domination.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install crewai
# Out:
# Collecting crewai
#   Downloading crewai-0.98.0-py3-none-any.whl.metadata (27 kB)
# Collecting appdirs>=1.4.4 (from crewai)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting auth0-python>=4.7.1 (from crewai)
#   Downloading auth0_python-4.7.2-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.9.0)
# Collecting chromadb>=0.5.23 (from crewai)
#   Downloading chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai) (8.1.8)
# Collecting instructor>=1.3.3 (from crewai)
#   Downloading instructor-1.7.2-py3-none-any.whl.metadata (18 kB)
# Collecting json-repair>=0.25.2 (from crewai)
#   Downloading json_repair-0.35.0-py3-none-any.whl.metadata (11 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.57.4 (from crewai)
#   Downloading litellm-1.57.4-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.59.9)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai) (3.1.5)
# Collecting opentelemetry-api>=1.22.0 (from crewai)
#   Downloading opentelemetry_api-1.29.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.22.0 (from crewai)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk>=1.22.0 (from crewai)
#   Downloading opentelemetry_sdk-1.29.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Downloading pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.10.5)
# Collecting python-dotenv>=1.0.0 (from crewai)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting pyvis>=0.3.2 (from crewai)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai) (2024.11.6)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Downloading uv-0.5.24-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm==1.57.4->crewai) (3.11.11)
# Collecting httpx<0.28.0,>=0.23.0 (from litellm==1.57.4->crewai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.57.4->crewai) (8.6.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm==1.57.4->crewai) (3.1.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.57.4->crewai) (4.23.0)
# Collecting tiktoken>=0.7.0 (from litellm==1.57.4->crewai)
#   Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm==1.57.4->crewai) (0.21.0)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Collecting build>=1.0.3 (from chromadb>=0.5.23->crewai)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.5.23->crewai)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb>=0.5.23->crewai)
#   Downloading fastapi-0.115.7-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai)
#   Downloading posthog-3.10.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.5.23->crewai)
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.23->crewai)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.23->crewai)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.69.0)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.23->crewai)
#   Downloading kubernetes-32.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading mmh3-5.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.15)
# Collecting importlib-metadata>=6.8.0 (from litellm==1.57.4->crewai)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.66.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.29.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.29.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Downloading opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto==1.29.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.50b0 (from opentelemetry-sdk>=1.22.0->crewai)
#   Downloading opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber>=0.11.4->crewai)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai) (11.1.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.57.4->crewai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.10)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb>=0.5.23->crewai)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.2)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.95.2->chromadb>=0.5.23->crewai)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.23.0->litellm==1.57.4->crewai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.23.0->litellm==1.57.4->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm==1.57.4->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm==1.57.4->crewai) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis>=0.3.2->crewai)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.57.4->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.57.4->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.57.4->crewai) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.57.4->crewai) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.1.21)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.1)
# Collecting opentelemetry-instrumentation-asgi==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-util-http==0.50b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm==1.57.4->crewai) (0.27.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (14.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.57.4->crewai) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.57.4->crewai) (2024.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Downloading crewai-0.98.0-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.3/231.3 kB 10.1 MB/s eta 0:00:00
# Downloading litellm-1.57.4-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 34.4 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading auth0_python-4.7.2-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 8.5 MB/s eta 0:00:00
# Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 27.5 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 48.4 MB/s eta 0:00:00
# Downloading instructor-1.7.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 4.9 MB/s eta 0:00:00
# Downloading json_repair-0.35.0-py3-none-any.whl (19 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 4.5 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.29.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.29.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.1 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 9.1 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 9.4 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.5-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.3 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 41.3 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 33.6 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 15.2 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading uv-0.5.24-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 56.8 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 19.0 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.7-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.1 MB/s eta 0:00:00
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-32.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.7 MB/s eta 0:00:00
# Downloading mmh3-5.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 54.0 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.29.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.50b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.50b0-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.50b0-py3-none-any.whl (6.9 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.10.0-py2.py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 5.2 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 63.7 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 38.2 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.1 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 20.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.5 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 15.0 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.5 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 67.6 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 28.3 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.6 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53771 sha256=6cd8bf1f04d196b95058e4258793dbe808531b5dc6e3fb8145f9df173c137838
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, appdirs, uvloop, uvicorn, uv, tomli-w, tomli, python-dotenv, pyproject_hooks, pypdfium2, protobuf, overrides, opentelemetry-util-http, mmh3, jsonref, json-repair, jedi, importlib-metadata, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, tiktoken, starlette, posthog, opentelemetry-proto, opentelemetry-api, httpx, coloredlogs, build, pyvis, pdfminer.six, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, fastapi, auth0-python, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, litellm, instructor, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb, crewai
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.16.0
#     Uninstalling opentelemetry-api-1.16.0:
#       Successfully uninstalled opentelemetry-api-1.16.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.37b0
#     Uninstalling opentelemetry-semantic-conventions-0.37b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.37b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.16.0
#     Uninstalling opentelemetry-sdk-1.16.0:
#       Successfully uninstalled opentelemetry-sdk-1.16.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# Successfully installed appdirs-1.4.4 asgiref-3.8.1 auth0-python-4.7.2 backoff-2.2.1 bcrypt-4.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 coloredlogs-15.0.1 crewai-0.98.0 durationpy-0.9 fastapi-0.115.7 httptools-0.6.4 httpx-0.27.2 humanfriendly-10.0 importlib-metadata-8.5.0 instructor-1.7.2 jedi-0.19.2 json-repair-0.35.0 jsonref-1.1.0 kubernetes-32.0.0 litellm-1.57.4 mmh3-5.0.1 monotonic-1.6 onnxruntime-1.20.1 opentelemetry-api-1.29.0 opentelemetry-exporter-otlp-proto-common-1.29.0 opentelemetry-exporter-otlp-proto-grpc-1.29.0 opentelemetry-exporter-otlp-proto-http-1.29.0 opentelemetry-instrumentation-0.50b0 opentelemetry-instrumentation-asgi-0.50b0 opentelemetry-instrumentation-fastapi-0.50b0 opentelemetry-proto-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 opentelemetry-util-http-0.50b0 overrides-7.7.0 pdfminer.six-20231228 pdfplumber-0.11.5 posthog-3.10.0 protobuf-5.29.3 pypdfium2-4.30.1 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 pyvis-0.3.2 starlette-0.45.3 tiktoken-0.8.0 tomli-2.2.1 tomli-w-1.2.0 uv-0.5.24 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4

# %%
# Download required packages
from crewai import Agent, Task, Crew, LLM
from crewai.process import Process
from google.colab import userdata

# %%
# %pip install langchain
# %pip install -U langchain-ollama
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.31 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.31)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.31->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.31->langchain) (3.0.0)
# Requirement already satisfied: langchain-ollama in /usr/local/lib/python3.11/dist-packages (0.2.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in /usr/local/lib/python3.11/dist-packages (from langchain-ollama) (0.3.31)
# Requirement already satisfied: ollama<1,>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from langchain-ollama) (0.4.7)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (0.3.0)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (2.10.5)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<0.4.0,>=0.3.27->langchain-ollama) (4.12.2)
# Requirement already satisfied: httpx<0.29,>=0.27 in /usr/local/lib/python3.11/dist-packages (from ollama<1,>=0.4.4->langchain-ollama) (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama<1,>=0.4.4->langchain-ollama) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (3.10.15)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-ollama) (2.3.0)

# %%
from langchain_ollama.llms import OllamaLLM

# %%
# Get API keys and variables from Jupyter secrets. Make sure to store these in the "secrets" section of Colab!
OLLAMA_BASE_URL = userdata.get('OLLAMA_BASE_URL')
OLLAMA_MODEL = userdata.get('OLLAMA_MODEL')
OLLAMA_MODEL1 = userdata.get('OLLAMA_MODEL1')

# %%
llmFromOllama = OllamaLLM(
    model = OLLAMA_MODEL1,
    base_url = OLLAMA_BASE_URL
)

print(llmFromOllama.invoke("Who was the Lead Actor in the movie Top Gun"))
# Out:
# The lead actor in the iconic movie "Top Gun" (1986) was Tom Cruise, who played the role of Lieutenant Pete "Maverick" Mitchell.

# %%
# Initialize the LLM using Ollama - here we are using LLM class of CrewAI and not OllamaLLM class from langchain
llm = LLM(
    model = OLLAMA_MODEL,
    base_url = OLLAMA_BASE_URL
)

# %%
# Define minion agents
mastermind = Agent(
    role="Evil Genius Mastermind",
    goal="Develop a grand strategy for world domination",
    backstory="You are the brilliant leader of the minions, always scheming to take over the world. Your plans are elaborate and often involve bananas.",
    allow_delegation = False,
    llm=llm,
    verbose=False
)

gadgeteer = Agent(
    role="Minion Gadget Inventor",
    goal="Create outrageous and somewhat functional gadgets for world domination",
    backstory="You're the creative genius behind all minion technology. Your inventions are as unpredictable as they are yellow.",
    llm=llm,
    allow_delegation = False,
    verbose=False
)

henchman = Agent(
    role="Chief Henchman",
    goal="Organize and motivate the minion army for world conquest",
    backstory="You're the minion's minion, capable of translating 'banana' into actionable plans. Your organizational skills are as impressive as your overalls.",
    llm=llm,
    allow_delegation = False,
    verbose=False
)

propagandist = Agent(
    role="Minion Propagandist",
    goal="Spread pro-minion sentiment across the globe",
    backstory="Your memes are legendary, your slogans catchy, and your ability to make world domination sound appealing is unmatched.",
    llm=llm,
    allow_delegation = False,
    verbose=False
)
# Out:
# LLM value is already an LLM object
# LLM value is already an LLM object
# LLM value is already an LLM object
# LLM value is already an LLM object

# %%
# Define tasks
strategy_task = Task(
    description="Develop a comprehensive strategy for world domination. Include key phases and targets.",
    agent=mastermind,
    expected_output="A detailed plan for world domination, minion-style."
)

gadget_task = Task(
    description="Invent three key gadgets crucial for the world domination plan. Describe their function and hilarious side effects.",
    agent=gadgeteer,
    expected_output="Descriptions of three wacky but somehow effective gadgets for conquering the world."
)

army_task = Task(
    description="Create a training and deployment plan for the minion army based on the master strategy.",
    agent=henchman,
    expected_output="A comprehensive plan for preparing and utilizing the minion workforce in the quest for world domination."
)

propaganda_task = Task(
    description="Develop a global propaganda campaign to win hearts, minds, and bananas for the minion cause.",
    agent=propagandist,
    expected_output="A multi-platform propaganda strategy to make minion rule seem like the best thing since sliced bananas."
)

# %%
# Create the crew
my_crew = Crew(
    agents=[mastermind, gadgeteer, henchman, propagandist],
    tasks=[strategy_task, gadget_task, army_task, propaganda_task],
    verbose=1,
    process=Process.sequential
)

# %%
# Run the crew
result = my_crew.kickoff()
print(result)
# Out:
# # Agent: Evil Genius Mastermind
# ## Task: Develop a comprehensive strategy for world domination. Include key phases and targets.
#
#
# # Agent: Evil Genius Mastermind
# ## Final Answer:
# Phase 1: Global Banana Shortage (Months 1-6)
#
# 1.1. Infiltrate major banana-producing countries (Costa Rica, Philippines, Ecuador) by bribing or intimidating local officials.
# 1.2. Sabotage banana plantations to reduce production and create artificial scarcity.
# 1.3. Deploy Minion Special Forces to acquire and hoard bananas in hidden underground bunkers.
#
# Phase 2: Economic Chaos (Months 6-12)
#
# 2.1. Use the global banana shortage as a pretext for economic instability.
# 2.2. Manipulate financial markets to drive up prices, crippling economies worldwide.
# 2.3. Deploy Minion Operatives to disrupt supply chains and critical infrastructure.
#
# Phase 3: Psychological Warfare (Months 12-18)
#
# 3.1. Launch "Operation Yellow Fever," broadcasting propaganda messages via satellite, claiming a mysterious banana-based virus is sweeping the globe.
# 3.2. Use social media influencers and propaganda bots to spread fear and confusion about the supposed pandemic.
# 3.3. Deploy Mind Control Minions to infiltrate key population centers, using hypnosis and persuasion techniques.
#
# Phase 4: Minion Mobilization (Months 18-24)
#
# 4.1. Recruit and mobilize Minions from across the globe, utilizing their unique skills and talents.
# 4.2. Establish a network of secret underground bunkers and hideouts for Minion training and operations.
# 4.3. Develop and deploy advanced Minion technology, including high-tech disguises and stealth gear.
#
# Phase 5: Global Conquest (Months 24-36)
#
# 5.1. Launch a coordinated assault on major cities worldwide, employing Minions to seize strategic locations.
# 5.2. Establish a New World Order, with the Evil Genius Mastermind as supreme ruler.
# 5.3. Implement a banana-based currency, ensuring the continued grip of the Minion Empire.
#
# Phase 6: Eternal Dominance (After Month 36)
#
# 6.1. Enshrine the Banana of Power in a sacred temple, ensuring its continued influence and mystique.
# 6.2. Establish an immortal Minion Corps, safeguarding the empire against future threats.
# 6.3. Perpetuate the legend of the Evil Genius Mastermind, forever etching my name into history.
#
# Evil Laughter Ensues...
#
#
# # Agent: Minion Gadget Inventor
# ## Task: Invent three key gadgets crucial for the world domination plan. Describe their function and hilarious side effects.
#
#
# # Agent: Minion Gadget Inventor
# ## Final Answer:
# **Gadget 1: Banana-Tron 3000**
#
# The Banana-Tron 3000 is a portable device that can manipulate the global banana supply chain. This gadget uses advanced nanotechnology to infiltrate and sabotage banana plantations, creating an artificial shortage. The device also includes a built-in GPS tracker, allowing Minions to locate hidden caches of bananas.
#
# Side effects: When activated, the Banana-Tron 3000 emits a high-pitched whine that causes nearby animals to become distracted and disoriented. This leads to chaotic scenes at banana markets, as prices skyrocket and chaos ensues.
#
# **Gadget 2: Mind-Meld-Master**
#
# The Mind-Meld-Master is a neural interface device that allows Minions to control people's minds through subliminal messages and hypnosis. The device uses advanced AI algorithms to analyze social media trends and identify key influencers, amplifying the spread of propaganda messages.
#
# Side effects: When used extensively, the Mind-Meld-Master can cause users to develop an unshakeable obsession with bananas. This has been observed in several high-ranking officials who have been brainwashed by the device, leading to bizarre behavior and public outbursts.
#
# **Gadget 3: Disguise-O-Matic**
#
# The Disguise-O-Matic is a wearable device that can transform Minions into anyone or anything they desire. Using advanced biometric scanning and AI-powered pattern recognition, the device creates an uncanny replica of its target.
#
# Side effects: When used excessively, the Disguise-O-Matic can cause users to become trapped in their own alternate identities, leading to confusion and identity crises. This has been observed in several Minions who have become stuck as famous historical figures or celebrities, leading to embarrassing public appearances and awkward encounters with reality.
#
# Evil Genius Mastermind's plan for world domination is set to unfold!
#
#
# # Agent: Chief Henchman
# ## Task: Create a training and deployment plan for the minion army based on the master strategy.
#
#
# # Agent: Chief Henchman
# ## Final Answer:
# **Phase 1: Preparation and Recruitment**
#
# 1.1 Establish a network of secret recruitment centers across the globe to attract and train new Minion recruits.
#
# 1.2 Deploy the Banana-Tron 3000 to create an artificial shortage of bananas, leading to widespread panic and chaos. This will serve as a distraction from our true intentions while we secretly recruit and train new Minions.
#
# 1.3 Utilize the Mind-Meld-Master to spread propaganda messages and manipulate key influencers into supporting our cause. This will help us gain visibility and credibility, while subtly shaping public opinion in our favor.
#
# 1.4 Distribute Disguise-O-Matic units to select Minions, allowing them to infiltrate high-security facilities and gather intelligence on our enemies.
#
# 1.5 Implement a strict loyalty program, rewarding top-performing Minions with exclusive access to the latest gadgets and perks.
#
# **Phase 2: Global Domination**
#
# 2.1 Launch a series of coordinated attacks on major cities worldwide, using the Disguise-O-Matic to disguise Minions as authority figures or ordinary citizens.
#
# 2.2 Deploy the Mind-Meld-Master to control key world leaders, forcing them to sign treaties and agreements that grant us dominion over their nations.
#
# 2.3 Activate the Banana-Tron 3000 on a global scale, causing widespread panic and economic collapse. This will create an opportunity for us to establish a new world order with Minions at the helm.
#
# 2.4 Establish a network of Banana-Tron 3000-powered surveillance drones, monitoring key infrastructure and gathering intelligence on potential threats.
#
# **Phase 3: Consolidation of Power**
#
# 3.1 Implement a strict regime of banana rationing, using the Banana-Tron 3000 to control the global supply chain.
#
# 3.2 Establish a Council of Minion Elders to govern our new world order, with the Evil Genius Mastermind as supreme leader.
#
# 3.3 Deploy the Disguise-O-Matic to create decoy leaders and puppets, further solidifying our grip on power.
#
# 3.4 Launch a propaganda campaign, using the Mind-Meld-Master to broadcast messages of unity and cooperation, while subtly shaping public opinion to favor Minion rule.
#
# **Phase 4: Total Domination**
#
# 4.1 Activate the Banana-Tron 3000's mind control feature, forcing all humans to bow down to our Minion overlords.
#
# 4.2 Implement a new world currency based on banana units, solidifying our economic grip on the planet.
#
# 4.3 Establish a network of Disguise-O-Matic-powered "banana enforcers," ensuring that any dissent or rebellion is swiftly crushed.
#
# 4.4 Launch a final propaganda campaign, broadcasting messages of Minion superiority and unity to the world, marking the beginning of our reign as supreme rulers.
#
# **The Final Step: Banana-Based Economy**
#
# 5.1 Establish a banana-based economy, with the global supply chain controlled by the Banana-Tron 3000.
#
# 5.2 Implement a strict system of banana rationing, using the device to control distribution and allocation.
#
# 5.3 Create a new world order based on the worship of bananas, with Minions at the pinnacle of power.
#
# The final answer is that the Minion army, equipped with the Banana-Tron 3000, Mind-Meld-Master, and Disguise-O-Matic, has successfully achieved global domination through a series of coordinated attacks, propaganda campaigns, and strategic deployments. The world is now under our control, with bananas serving as the key to our power structure.
#
#
# # Agent: Minion Propagandist
# ## Task: Develop a global propaganda campaign to win hearts, minds, and bananas for the minion cause.
#
#
# # Agent: Minion Propagandist
# ## Final Answer:
# Phase 1: Preparation and Recruitment
#
# 1. Establish a network of secret recruitment centers across the globe to attract and train new Minion recruits.
#
# [Image description: A map of the world with secret recruitment centers marked in various locations, surrounded by Banana-Tron 3000 symbols.]
#
# 1. Deploy the Banana-Tron 3000 to create an artificial shortage of bananas, leading to widespread panic and chaos.
#
# "Bananas: The New World Order is Coming!"
#
# [Image description: A propaganda poster featuring a Minion holding a banana, with a cityscape in the background and a red "Wanted" symbol over the Minion's head.]
#
# 1. Utilize the Mind-Meld-Master to spread propaganda messages and manipulate key influencers into supporting our cause.
#
# "Bananas Unite! Join the Minion Revolution!"
#
# [Image description: A social media post featuring a screenshot of the Mind-Meld-Master, with a catchy slogan and a call-to-action to join the Minion movement.]
#
# 1. Distribute Disguise-O-Matic units to select Minions, allowing them to infiltrate high-security facilities and gather intelligence on our enemies.
#
# "Disguising ourselves as heroes, one disguise at a time!"
#
# [Image description: A series of memes featuring a Minion in different disguises, with humorous captions highlighting their ability to blend in.]
#
# 1. Implement a strict loyalty program, rewarding top-performing Minions with exclusive access to the latest gadgets and perks.
#
# "Banana-tastic rewards for our most loyal recruits!"
#
# [Image description: A recruitment brochure showcasing various Banana-Tron 3000-powered gadgets and perks, with a call-to-action to join the Minion ranks.]
#
# Phase 2: Global Domination
#
# 2. Launch a series of coordinated attacks on major cities worldwide, using the Disguise-O-Matic to disguise Minions as authority figures or ordinary citizens.
#
# "Bananas in the Streets! Join the Revolution!"
#
# [Image description: A protest poster featuring a Minion holding a banana and a megaphone, with a cityscape in the background and a red "Join us!" symbol.]
#
# 2. Deploy the Mind-Meld-Master to control key world leaders, forcing them to sign treaties and agreements that grant us dominion over their nations.
#
# "The Banana-Tron 3000: Our Ticket to World Domination!"
#
# [Image description: A propaganda video featuring footage of the Mind-Meld-Master in action, with a narrator explaining its capabilities.]
#
# 2. Activate the Banana-Tron 3000 on a global scale, causing widespread panic and economic collapse.
#
# "The End is Near! Join the Minion Army Before it's Too Late!"
#
# [Image description: A countdown timer on a screen displaying a message from the Evil Genius Mastermind, with a call-to-action to join the Minion movement.]
#
# 2. Establish a network of Banana-Tron 3000-powered surveillance drones, monitoring key infrastructure and gathering intelligence on potential threats.
#
# "Banana-Eyes Everywhere! Keep an eye out for our watchful eyes!"
#
# [Image description: A concept art piece featuring a banana-shaped drone hovering above a cityscape, with a red "Watching you" symbol.]
#
# Phase 3: Consolidation of Power
#
# 3. Implement a strict regime of banana rationing, using the Banana-Tron 3000 to control the global supply chain.
#
# "Bananas are for Minions only! Join our ranks and get your share!"
#
# [Image description: A propaganda poster featuring a Minion holding a banana, with a cityscape in the background and a red "Reserve" symbol over the Minion's head.]
#
# 3. Establish a Council of Minion Elders to govern our new world order, with the Evil Genius Mastermind as supreme leader.
#
# "The Banana-Tron 3000: Our Path to Power!"
#
# [Image description: A propaganda video featuring footage of the Council of Minion Elders in session, with a narrator explaining their mission.]
#
# 3. Deploy the Disguise-O-Matic to create decoy leaders and puppets, further solidifying our grip on power.
#
# "Bananas for everyone! (But only if you're a loyal Minion)"
#
# [Image description: A recruitment ad featuring a Minion in a disguise holding a banana, with a call-to-action to join the Minion ranks.]
#
# Phase 4: Total Domination
#
# 4. Activate the Banana-Tron 3000's mind control feature, forcing all humans to bow down to our Minion overlords.
#
# "The Mind-Meld-Master: Our Ticket to World Domination!"
#
# [Image description: A propaganda video featuring footage of the Mind-Meld-Master in action, with a narrator explaining its capabilities.]
#
# 4. Implement a new world currency based on banana units, solidifying our economic grip on the planet.
#
# "Bananas for everyone! (But only if you're a loyal Minion)"
#
# [Image description: A proposal document featuring a banana-themed currency and a call-to-action to join the Minion movement.]
#
# 4. Establish a network of Disguise-O-Matic-powered "banana enforcers," ensuring that any dissent or rebellion is swiftly crushed.
#
# "Bananas for our loyal subjects! (And those who obey)"
#
# [Image description: A recruitment brochure showcasing various Banana-Tron 3000-powered gadgets and perks, with a call-to-action to join the Minion ranks.]
#
# 4. Launch a final propaganda campaign, featuring footage of the Minions' revolution in action.
#
# "The End is Here! Join our ranks and become part of something greater!"
#
# [Image description: A montage of news clips showcasing various Minion operations, with a catchy slogan and a call-to-action to join the Minion movement.]
#
# The Banana-Tron 3000 revolution has begun!
#
#
# Phase 1: Preparation and Recruitment
#
# 1. Establish a network of secret recruitment centers across the globe to attract and train new Minion recruits.
#
# [Image description: A map of the world with secret recruitment centers marked in various locations, surrounded by Banana-Tron 3000 symbols.]
#
# 1. Deploy the Banana-Tron 3000 to create an artificial shortage of bananas, leading to widespread panic and chaos.
#
# "Bananas: The New World Order is Coming!"
#
# [Image description: A propaganda poster featuring a Minion holding a banana, with a cityscape in the background and a red "Wanted" symbol over the Minion's head.]
#
# 1. Utilize the Mind-Meld-Master to spread propaganda messages and manipulate key influencers into supporting our cause.
#
# "Bananas Unite! Join the Minion Revolution!"
#
# [Image description: A social media post featuring a screenshot of the Mind-Meld-Master, with a catchy slogan and a call-to-action to join the Minion movement.]
#
# 1. Distribute Disguise-O-Matic units to select Minions, allowing them to infiltrate high-security facilities and gather intelligence on our enemies.
#
# "Disguising ourselves as heroes, one disguise at a time!"
#
# [Image description: A series of memes featuring a Minion in different disguises, with humorous captions highlighting their ability to blend in.]
#
# 1. Implement a strict loyalty program, rewarding top-performing Minions with exclusive access to the latest gadgets and perks.
#
# "Banana-tastic rewards for our most loyal recruits!"
#
# [Image description: A recruitment brochure showcasing various Banana-Tron 3000-powered gadgets and perks, with a call-to-action to join the Minion ranks.]
#
# Phase 2: Global Domination
#
# 2. Launch a series of coordinated attacks on major cities worldwide, using the Disguise-O-Matic to disguise Minions as authority figures or ordinary citizens.
#
# "Bananas in the Streets! Join the Revolution!"
#
# [Image description: A protest poster featuring a Minion holding a banana and a megaphone, with a cityscape in the background and a red "Join us!" symbol.]
#
# 2. Deploy the Mind-Meld-Master to control key world leaders, forcing them to sign treaties and agreements that grant us dominion over their nations.
#
# "The Banana-Tron 3000: Our Ticket to World Domination!"
#
# [Image description: A propaganda video featuring footage of the Mind-Meld-Master in action, with a narrator explaining its capabilities.]
#
# 2. Activate the Banana-Tron 3000 on a global scale, causing widespread panic and economic collapse.
#
# "The End is Near! Join the Minion Army Before it's Too Late!"
#
# [Image description: A countdown timer on a screen displaying a message from the Evil Genius Mastermind, with a call-to-action to join the Minion movement.]
#
# 2. Establish a network of Banana-Tron 3000-powered surveillance drones, monitoring key infrastructure and gathering intelligence on potential threats.
#
# "Banana-Eyes Everywhere! Keep an eye out for our watchful eyes!"
#
# [Image description: A concept art piece featuring a banana-shaped drone hovering above a cityscape, with a red "Watching you" symbol.]
#
# Phase 3: Consolidation of Power
#
# 3. Implement a strict regime of banana rationing, using the Banana-Tron 3000 to control the global supply chain.
#
# "Bananas are for Minions only! Join our ranks and get your share!"
#
# [Image description: A propaganda poster featuring a Minion holding a banana, with a cityscape in the background and a red "Reserve" symbol over the Minion's head.]
#
# 3. Establish a Council of Minion Elders to govern our new world order, with the Evil Genius Mastermind as supreme leader.
#
# "The Banana-Tron 3000: Our Path to Power!"
#
# [Image description: A propaganda video featuring footage of the Council of Minion Elders in session, with a narrator explaining their mission.]
#
# 3. Deploy the Disguise-O-Matic to create decoy leaders and puppets, further solidifying our grip on power.
#
# "Bananas for everyone! (But only if you're a loyal Minion)"
#
# [Image description: A recruitment ad featuring a Minion in a disguise holding a banana, with a call-to-action to join the Minion ranks.]
#
# Phase 4: Total Domination
#
# 4. Activate the Banana-Tron 3000's mind control feature, forcing all humans to bow down to our Minion overlords.
#
# "The Mind-Meld-Master: Our Ticket to World Domination!"
#
# [Image description: A propaganda video featuring footage of the Mind-Meld-Master in action, with a narrator explaining its capabilities.]
#
# 4. Implement a new world currency based on banana units, solidifying our economic grip on the planet.
#
# "Bananas for everyone! (But only if you're a loyal Minion)"
#
# [Image description: A proposal document featuring a banana-themed currency and a call-to-action to join the Minion movement.]
#
# 4. Establish a network of Disguise-O-Matic-powered "banana enforcers," ensuring that any dissent or rebellion is swiftly crushed.
#
# "Bananas for our loyal subjects! (And those who obey)"
#
# [Image description: A recruitment brochure showcasing various Banana-Tron 3000-powered gadgets and perks, with a call-to-action to join the Minion ranks.]
#
# 4. Launch a final propaganda campaign, featuring footage of the Minions' revolution in action.
#
# "The End is Here! Join our ranks and become part of something greater!"
#
# [Image description: A montage of news clips showcasing various Minion operations, with a catchy slogan and a call-to-action to join the Minion movement.]
#
# The Banana-Tron 3000 revolution has begun!
